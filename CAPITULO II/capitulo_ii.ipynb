# %% [markdown]
# # TIPOS DE OBJETOS EN PYTHON:

# %% [markdown]
# INMUTABLES:

# %%
#OBJETOS INMUTABLES DENTRO DE PYTHON

numero_entero = 10    #int

numero_flotante = 3.14    #float

mi_cadena = "Python"    #str

mi_tupla = (1, 2, 3)    #tuple

mi_rango = range(5)   #range

mi_frozenset = frozenset([1, 2, 3])   #version inmutable de un set

# %%
#por el momento solo vamos a trabajar con lo siguientes objetos

#int
#float
#str
#tuple
#range

# %% [markdown]
# # a que se debe que int, float y str sean inmutables si los podemos modificar?

# %%
"""En realidad lo que modficamos son los valores que luego se guardan en otro lugar de la memoria"""

#ejemplo:

numero = 5

print(f"El identificador de memoria es {id(numero)}")

numero += 1

print(f"El nuevo identificador de memoria es {id(numero)}")
# Out:
# El identificador de memoria es 11642216
# El nuevo identificador de memoria es 11642248

# %% [markdown]
# # Ya sabemos como utilizar los tipos int, float, str y range.
# # Veremos como se uitiliza el tipo tuple

# %%
#Ejemplo de una tupla dentro de python

tupla = (2,5,6,8,"ddd",["s",6]) # -> se declara con los parentesis
tupla1 = (2,5,5)
tupla
# Out:
# (2, 5, 6, 8, 'ddd', ['s', 6])

# %%
"""donde podemos acceder a los datos guardados de la misma manera en la que accediamos a las listas"""

print(tupla[0], " ", tupla[5])

print(f"{tupla[1]} {tupla[4]}")

print(tupla[-3])
# Out:
# 2   ['s', 6]
# 5 ddd
# 8

# %%
"""debido a su naturaleza NO PODEMOS MODIFICAR SU CONTENIDO UNA VEZ DECLARADO"""
tupla[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2674306228.py in <cell line: 0>()
#       1 """debido a su naturaleza NO PODEMOS MODIFICAR SU CONTENIDO UNA VEZ DECLARADO"""
# ----> 2 tupla[0] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
""" por ende no existen metodos que modifiquen su contenido"""

#METODOS DISPONIBLES PARA EL MANEJO DE TUPLAS:

#.count()

"""nos indica la cantidad de veces que aparece un elemento dentro de nuestra tupla"""

print(f"el valor {tupla[0]} aparece {tupla.count(tupla[0])}")

#.index()

"""nos da la primera posicion de un valor en especifico dentro de la tupla"""
"""posicion que inicia en el 0 y termina en n-1, con n siendo el numero total de elementos de la tupla"""

print(f"el valor 5 tiene la posicion {tupla.index(5)}")
# Out:
# el valor 2 aparece 1
# el valor 5 tiene la posicion 1

# %% [markdown]
# # parentesis 😒
# # refresquemos la deficion de metodo en python

# %%
"""Un método es una función que está asociada a un objeto"""

"""por ende no todos los objetos van a compartir los mismos metodos"""

#veremos ejemplos mas adelante :)

# %% [markdown]
# # fin del parentesis 😎

# %% [markdown]
# # **Operaciones con tuplas**

# %%
print(f"tupla original : {tupla}")

# rebanado

tupla_nueva = tupla[0:3]

print(f"la tupla rebanada : {tupla_nueva}")

#asignacion a variables

variable_x = tupla[3]

print(f"variable que pudimos extraer {variable_x}")
# Out:
# tupla original : (2, 5, 6, 8, 'ddd', ['s', 6])
# la tupla rebanada : (2, 5, 6)
# variable que pudimos extraer 8

# %% [markdown]
# # Ya revisamos lo que nos interesaba de los tipos de datos inmutables en python
# # despues volveremos a verlos

# %% [markdown]
# MUTABLES:

# %%
# Objetos mutables dentro de python

lista = [2,6,3,6,"ddd",5.2,[4,5],4 + 4j]    #list

diccionario = {43 : "PEPE", 56 : "VEGETA777", 85 : [1,12,3], "44" : 45}   #dicc

set_nuevo = {5,5,5,3,7}   #set

# %%
#por el momento solo vamos a trabajar con los siguientes objetos

#list

#dicc

# %% [markdown]
# # LISTAS DENTRO DE PYTHON

# %%
""" pueden declarase de dos formas """

#con corchetes
lista_1 = [1,5,2]

#con la funcion list()

lista_2 = list(range(5))

print(f"primera lista: {lista_1}; segunda lista : {lista_2}")
# Out:
# primera lista: [1, 5, 2]; segunda lista : [0, 1, 2, 3, 4]

# %%
# podemos modificar los elementos que componen los valores dentro de las listas

lista_1[0] = "ddddddd"

print(f"Mi nueva lista es : {lista_1}")
# Out:
# Mi nueva lista es : ['ddddddd', 5, 2]

# %%
print(lista_1[0])
# Out:
# ddddddd

# %%
#aproximamos los datos de igual forma en la que se hace con las tuplas

print(f"el elemento numero 1 de la lista es : {lista_1[0]}")
# Out:
# el elemento numero 1 de la lista es : ddddddd

# %%
# IMPORTANTE 😊

""" la funcion list() es un constructor que nos puede permitir dos cosas """

#crear una lista vacia
ejemplo_1 = list()

print(ejemplo_1)

#tomar un objeto iterable y convertirlo en una lista

print(lista_2)
# Out:
# []
# [0, 1, 2, 3, 4]

# %% [markdown]
# # parentesis 😒
# # refresquemos la deficion de iterables dentro de python

# %%
"""En Python, un objeto es iterable si puede ser recorrido, es decir, si puede devolver sus elementos uno por uno"""

#listas
#tuplas
#str
#rango
#diccionarios

"""por el momento solo nos interesan esos"""

# %% [markdown]
# # fin del parentesis 😎

# %%
""" vamos a utlizar la funcion list() en todos estos objetos"""

# con una tupla
my_list_1 = list(tupla) # -> se lleva los elemntos que componen la tupla

print(my_list_1)

#con un str
my_list_2 = list("hola a todos")  # -> se lleva los caracteres que componene el string

print(my_list_2)

#con un diccionario
my_list_3 = list(diccionario) # -> solo se lleva las claves  la lista

print(my_list_3)

"""ya vimos como se comporta utilizando la funcion range()"""
# Out:
# [2, 5, 6, 8, 'ddd', ['s', 6]]
# ['h', 'o', 'l', 'a', ' ', 'a', ' ', 't', 'o', 'd', 'o', 's']
# [43, 56, 85, '44']

# %%
""" revisaremos los metodos disponibles para las listas en python"""

"""metodos para añadir elementos"""
lista = list(range(4))

print(f"lista original -> {lista}")

#.append()
"""añande un elemento al final de una lista"""

lista.append("ssss")

print(f"lista utilzando append -> {lista}")

#.extend()
"""añade un objeto iterable al final de la lista"""
"""podemos añadir otra lista o tuplas"""

lista.extend(range(2))

print(f"lista utilizando extend -> {lista}")

#.insert()
"""añade un elemento en una posicion especifica de la lista"""
"""si el indice supera el que permite la lista lo inserta al final"""

lista.insert(8, "añadido")

print(f"lista utilizando insert -> {lista}")
# Out:
# lista original -> [0, 1, 2, 3]
# lista utilzando append -> [0, 1, 2, 3, 'ssss']
# lista utilizando extend -> [0, 1, 2, 3, 'ssss', 0, 1]
# lista utilizando insert -> [0, 1, 2, 3, 'ssss', 0, 1, 'añadido']

# %%
""" metedos para eliminar elementos"""

#.remove()
"""remueve la primera coincidencia de un valor"""

lista.remove(1)

print(f"lista utilizando remove -> {lista}")

#.pop()
"""elimina el valor en una posicion especifica y lo devuelve"""
"""si no se especifica el indice elimina el ultimo valor de la lista"""

valor = lista.pop()

print(f"lista utilizando pop -> {lista} se elimino el {valor}")

#.clear()
"""elimina todos los elementos de la lista dejandola vacia"""
lista_aux = list(range(5))

lista_aux.clear()

print(f"lista utilizando clear -> {lista_aux}")
# Out:
# lista utilizando remove -> [0, 2, 3, 'ssss', 0, 1, 'añadido']
# lista utilizando pop -> [0, 2, 3, 'ssss', 0, 1] se elimino el añadido
# lista utilizando clear -> []

# %%
"""metodo de ordenacion y reversion """
lista = list(range(5))

#.sort()
"""solo ordena listas con numeros"""
lista.sort()

print(f"lista utilizando sort -> {lista}")

#.reverse()
"""ordena de forma reversa la lista"""
lista.reverse()

print(f"lista utilizando reverse -> {lista}")
# Out:
# lista utilizando sort -> [0, 1, 2, 3, 4]
# lista utilizando reverse -> [4, 3, 2, 1, 0]

# %%
lista_auxilar = [2,0,1,5,"Jose"]
variable = lista_auxilar.pop()
lista_auxilar.sort()
lista_auxilar.append(variable)
lista_auxilar
# Out:
# [0, 1, 2, 5, 'Jose']

# %%
lista_auxilar = [2,0,1,5,"Jose"]
lista_auxilar[:4].sort()
print(lista_auxilar)

print(f"id de {id(lista_auxilar)} y id de {id(lista_auxilar[:4])}")
# Out:
# [2, 0, 1, 5, 'Jose']
# id de 138251923426432 y id de 138251920789312

# %%
lista_3 = [1,2,1 + 4j,16]
lista_3.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-925574231.py in <cell line: 0>()
#       1 lista_3 = [1,2,1 + 4j,16]
# ----> 2 lista_3.sort()
#
# TypeError: '<' not supported between instances of 'complex' and 'int'

# %%
"""metodos de consula"""

#.count()
"""cuenta la cantidad de veces que aparece un determinado elemento"""

cont = lista.count(1)

print(f"lista utilizando count -> {lista} el 1 aparecio {cont} veces")

#.copy()
"""copia el contenido de la lista"""
"""no modifica la lista original"""

lista_nueva = lista.copy()

print(f"lista utilizando copy -> {lista} y la otra lista es {lista_nueva}")

#.index()
"""retorna el indice de la primera aparicion de un elemento"""

indice = lista.index(1)

print(f"lista utilizando index -> {lista} el 1 tiene indice {indice}")
# Out:
# lista utilizando count -> [4, 3, 2, 1, 0] el 1 aparecio 1 veces
# lista utilizando copy -> [4, 3, 2, 1, 0] y la otra lista es [4, 3, 2, 1, 0]
# lista utilizando index -> [4, 3, 2, 1, 0] el 1 tiene indice 3

# %% [markdown]
# # parentesis 😒
# # refresquemos como funciona la asignacion de variables en python

# %%
"""la funcion id() nos devolvera la direccion de memoria donde el objeto esta almacenado"""

variable1 = list(range(4))

print(f"el id de memoria de variable1 es {id(variable1)}")

variable2 = variable1

print(f"el id de memoria de variable2 es {id(variable2)}")

#si modificamos la variable2

variable2.clear()

print(f"variable1 : {variable1} y variable2 : {variable2}")

#lo correcto seria utilizar copy para operar en otra lista diferente
# Out:
# el id de memoria de variable1 es 132652673816320
# el id de memoria de variable2 es 132652673816320
# variable1 : [] y variable2 : []

# %%
variable1 = list(range(4))

print(f"el id de memoria de variable1 es {id(variable1)}")

variable2 = variable1.copy()

print(f"el id de memoria de variable2 es {id(variable2)}")

print(f"lista1 {variable1} lista2 {variable2}")

#si modificamos la variable2

variable2.clear()

print(f"variable1 : {variable1} y variable2 : {variable2}")
# Out:
# el id de memoria de variable1 es 138251917268672
# el id de memoria de variable2 es 138251917301568
# lista1 [0, 1, 2, 3] lista2 [0, 1, 2, 3]
# variable1 : [0, 1, 2, 3] y variable2 : []

# %% [markdown]
# # fin del parentesis 😎

# %% [markdown]
# # FUNCIONES QUE SE LES PUEDEN APLICAR A LAS LISTAS EN PYTHON

# %%
#funcion len()
""" retorna el numero de elementos que posee la lista"""
""" en general se puede aplicar a cualquie objeto iterable"""

print(f"largo de la lista -> {len(lista)}")
print(f"largo de la tupla -> {len(tupla)}")
print(f"largo del rango -> {len(range(4))}")
print(f"largo del diccionario -> {len(diccionario)}")
# Out:
# largo de la lista -> 5
# largo de la tupla -> 6
# largo del rango -> 4
# largo del diccionario -> 4

# %%
#funcion sorted()
""" retorna una nueva lista con los elementos de la lista anterior ordenados"""

lista1 = sorted(lista)

print(f"la lista resultante es {lista1}")
print(f"lista tiene id : {id(lista)} y lista1 tiene id : {id(lista1)}")
# Out:
# la lista resultante es [0, 1, 2, 3, 4]
# lista tiene id : 132652675407360 y lista1 tiene id : 132652672494976

# %%
#min() y max()
"""devuelven el valor minimo y el valor maximo respectivamente"""

print(f"el valor minimo de la lista -> {min(lista)} y el valor maximo de la lista -> {max(lista)}")
# Out:
# el valor minimo de la lista -> 0 y el valor maximo de la lista -> 4

# %%
#sum()
"""suma todos los elementos de una lista"""

print(f"la suma de todos los elemetos de la lista -> {sum(lista)}")
# Out:
# la suma de todos los elemetos de la lista -> 10

# %%
#str()
"""devuelve un string"""

print(f"de la lista se obtiene la cadena -> {str(lista)}")
# Out:
# de la lista se obtiene la cadena -> [4, 3, 2, 1, 0]

# %% [markdown]
# # **dato curioso... 🙄**

# %%
#pueden calcular las sumas de todos los elementos de un rango mediante la formula de Gauss

#donde n es el ultimo elemento del rango entonces suma = (n*(n+1))/2

"""utilicemos esto en un caso practico"""

valor_maximo = max(lista)

print(f"el valor maximo de la lista es -> {valor_maximo}")

suma = (valor_maximo * (valor_maximo + 1)) / 2

print(f"su suma es -> {int(suma)}")
# Out:
# el valor maximo de la lista es -> 4
# su suma es -> 10

# %% [markdown]
# asi ya saben como hacer su propia funcion de suma para todos los numeros enteros entre 0 y n siendo n ∈ Ζ positivos...
# # de nada 😗

# %%
#tambien podemos cortar las listas como con las tuplas

# %% [markdown]
# # **DICCIONARIOS DENTRO DE PYTHON**

# %%
diccionario = {2 : [5,5,5] , "carne" : ["vaca" , "pollo"] , "4": "d" , "marcelo" : 2}

""" se guardan mediante un par clave valor"""
""" no admite claves duplicadas, sobreescribe la utlimna"""

#acedemos a los datos por su clave

print(diccionario[2])

#podemos sobreescribirlo mediante la clave

diccionario[2] = "america"

print(diccionario[2])

#si el indice no existe se crea un nuevo apartado

diccionario[3] = "Danny"

print(diccionario)
# Out:
# [5, 5, 5]
# america
# {2: 'america', 'carne': ['vaca', 'pollo'], '4': 'd', 'marcelo': 2, 3: 'Danny'}

# %%
"""revisaremos los metodos de los diccionarios dentro de python"""

"""metodos para añadir y actualizar"""

#.update()
"""inserta un diccionario dentro de otro """
diccionario1 = {2 : 5}
diccionario.update(diccionario1)

print(f"usando update -> {diccionario}")

#.fromkeys()
"""crea un diccionario nuevo con una lista de claves y con un valor dado"""
claves = [5,4,6,8]
diccionario1 = dict.fromkeys(claves, 0)

print(f"usando fromkeys -> {diccionario1}")
# Out:
# usando update -> {2: 5, 'carne': ['vaca', 'pollo'], '4': 'd', 'marcelo': 2, 3: 'Danny'}
# usando fromkeys -> {5: 0, 4: 0, 6: 0, 8: 0}

# %%
"""metodos de eliminacion"""
#.pop()
"""Elimina la clave especificada y devuelve su valor"""

diccionario.pop(2)
print(f"usando pop -> {diccionario}")

#.popitem()
"""elimina y devuelve el ultimo par clave- valor ingresado en el diccionario"""

clave_valor = diccionario.popitem()

print(f"usando popitem -> {diccionario}, nos quedo el par {valor}")

#.clear()
"""limpia el diccionario """
diccionario1 = {2 : "s"}

diccionario1.clear()

print(f"usando clear -> {diccionario1}")
# Out:
# usando pop -> {'carne': ['vaca', 'pollo'], '4': 'd', 'marcelo': 2, 3: 'Danny'}
# usando popitem -> {'carne': ['vaca', 'pollo'], '4': 'd', 'marcelo': 2}, nos quedo el par añadido
# usando clear -> {}

# %%
"""metodos de acceso y vista """

#.get()
"""devuelve el valor para una clave dada"""

valor = diccionario.get(4)

print(f"usando get -> {valor}")

#.keys()
"""devuelve un objeto vista con todas las claves"""

valor = diccionario.keys()

print(f"usando keys -> {valor}")

#.values()
"""devuelve un objeto vista con todos los valores"""

valor = diccionario.values()

print(f"usando values -> {valor}")

#.items()
"""devuelve un objeto vista con todos los pares clave valor que tiene el diccionario"""

valor = diccionario.items()

print(f"usando items -> {valor}")
# Out:
# usando get -> None
# usando keys -> dict_keys(['carne', '4', 'marcelo'])
# usando values -> dict_values([['vaca', 'pollo'], 'd', 2])
# usando items -> dict_items([('carne', ['vaca', 'pollo']), ('4', 'd'), ('marcelo', 2)])

# %% [markdown]
# # parentesis 😒
# # que es un objeto vista

# %%
"""Un objeto vista en Python es una vista dinámica y en tiempo real del contenido de un objeto, como un diccionario, conjunto o lista.
No es una copia de los datos, sino una ventana a los elementos del objeto original. """

# si el objeto cambia se actualiza automaticamente
# es iterable
# es inmutable

# %% [markdown]
# # fin del parentesis 😎

# %%
"""metodo de copia """

#.copy()
"""copia el contenido a otro diccionario """
"""aplica el mismo manejo de memoria quen las listas"""

diccionario1 = diccionario.copy()

print(f"usando copy -> {diccionario1}")
# Out:
# usando copy -> {'carne': ['vaca', 'pollo'], '4': 'd', 'marcelo': 2}

# %% [markdown]
# # funciones que se les pueden aplicar

# %%
"""todas las que se les pueden aplicar a las listas se les pueden aplicar a los diccionarios...
con algunos detalles"""

# %% [markdown]
# # dato curioso... 🙄
# # OBLIGATORIO 🙄²

# %%
import json

persona_diccionario = {
    "nombre": "Ana",
    "edad": 30,
    "ciudad": "Madrid"
}

# Convierte el diccionario a una cadena JSON
json_string = json.dumps(persona_diccionario, indent=4)
print("Cadena JSON:")
print(json_string)

# %%
"""ASI SE PUEDE CREAR DICCIONARIOS PARA LUEGO SER CONVERTIFOS EN FORMATO JSON"""
