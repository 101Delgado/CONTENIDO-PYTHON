# %% [markdown]
# # APRENDIZAJE AUTOMATICO

# %% [markdown]
# ![flat,750x,075,f-pad,750x1000,f8f8f8.jpg](data:image/jpeg;base64,...)

# %%
"""
El aprendizaje automático (Machine Learning, en inglés) es un subcampo de la
ciencia de la computación y una rama de la inteligencia artificial (IA).
Su objetivo es desarrollar técnicas que permitan a las computadoras aprender
de los datos y mejorar su rendimiento con el tiempo,
sin ser programadas explícitamente para cada tarea
"""

# %%
"""
El aprendizaje automático difiere de la programación tradicional en la forma
en que se crea el "algoritmo" o modelo:
"""

"""
1) Programación Tradicional: Se dan a la computadora datos y reglas
(algoritmos explícitos), y se obtiene una respuesta o resultado.

2) Aprendizaje Automático: Se dan a la computadora datos y las respuestas
correctas (etiquetas), y la máquina genera un modelo
(un conjunto de reglas o un algoritmo matemático) que puede determinar
la lógica o los patrones subyacentes.
"""

"""
Este modelo, a diferencia de un algoritmo tradicional estático,
puede ser entrenado continuamente con nuevos datos para refinar su
capacidad de hacer predicciones o clasificaciones precisas.
"""

# %% [markdown]
# ![4b46ba6bff7ed17311ca99756bff1e49.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# APRENDIZAJE SUPERVISADO

# %%
# El algoritmo se entrena con datos etiquetados, es decir, pares de datos de entrada y su salida esperada o correcta.

# El objetivo es que el modelo aprenda a mapear las entradas a las salidas para poder predecir la etiqueta de datos nuevos e invisibles.

# %% [markdown]
# APRENDIZAJE NO SUPERVISADO

# %%
# El algoritmo aprende a partir de datos no etiquetados.

# Se enfoca en identificar patrones, estructuras, o relaciones dentro de los propios datos.

# %% [markdown]
# APRENDIZAJE POR REFUERZO

# %%
# El algoritmo aprende mediante prueba y error al interactuar con un entorno.

# Recibe retroalimentación en forma de recompensas (positiva) o penalizaciones (negativa), ajustando sus acciones para maximizar la recompensa acumulada.

# Ejemplo: Enseñar a una máquina a jugar ajedrez o a navegar en un entorno virtual.

# %% [markdown]
# # FLUJO DE TRABAJO

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %% [markdown]
# # TIPOS DE APRENDIZAJE AUTOMATICO (ALGORITMOS)

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %% [markdown]
# # AHORA HABLAREMOS DE LA REGRESION LINEAL

# %%
"""
APRENDIZAJE SUPERVISADO
"""

"""
La regresión lineal es una técnica de análisis de datos y uno de los
modelos más básicos y fundamentales del aprendizaje automático supervisado.

Su objetivo es encontrar la línea recta que mejor se ajusta a un conjunto
de datos para modelar la relación entre una variable dependiente (Y)
y una o más variables independientes (X).
"""

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %% [markdown]
# # ES IMPORTANTE DESTACAR ALGO 😮

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %% [markdown]
# COEFICIENTES DE REGRESION

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %%
"""
CAPTURAN LOS DATOS DEL MODELO, SON LOS PARAMETROS DEL MODELO
"""

# %% [markdown]
# COEFICIENTE DE ERROR

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %% [markdown]
# COMO SE VE ESO

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %%
"""
LO QUE BUSCAMOS ES REDUCIR AL MINIMO LA DISTANCIA VERTICAL DEL PUNTO (VALOR ESPERADO)
A LA RECTA, VALOR PREDICHO
"""

# %% [markdown]
# CALCULO DEL ERROR

# %%
"""
El método MCO (Mínimos Cuadrados Ordinarios) busca elegir β0​ y β1​ de tal manera que la suma de los cuadrados
de todos los residuos sea la más pequeña posible.
Este es el criterio que se minimiza:
"""

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %%
"""
Todo suena muy bonito hasta que nos damos cuenta que para el manejo de multiples
variables independientes tenemos que utilizar el algebra matricial
"""

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %%
"""
Esta es la forma compacta de escribir las regresiones multiples
y la forma en la que lo calcula nuestro pequeño equipo
"""

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %%
"""
de esta forma luce la matriz de diseño o matriz de regresores donde cada linea
corresponde con una observacion de un caso dentro de nuestro data frame, y cada
columna corresponde con una columna del mismo (variable)
"""

# %% [markdown]
# # COLUMNA DE 1 🤔

# %%
"""
Esta columna es esencial para que el cálculo matricial de Mínimos Cuadrados Ordinarios
(MCO) pueda estimar el coeficiente del intercepto (β^​0​).
Matemáticamente, representa el término que no está multiplicado por ninguna variable.
"""

# %% [markdown]
# COMO CALCULAR CUALQUIERA DE LOS CASOS EN SU DEFECTO

# %%
  """
  Anteriormente nosotros habiamos dicho que el proposito era minimizar el error
  epsilon
  """

# %%
# usemos derivadas...

# %% [markdown]
# ![5b07c3627ae7a33f3fb504f4d50bf60b.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # PROBLEMAS DE MAXIMIZACION (REVISEN CALCULO)

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %%
"""
tenemos entonces el siguiente sistema de ecuaciones
"""

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %% [markdown]
# CONSIDERANDO LO SIGUIENTE

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %% [markdown]
# AL FINAL NOS QUEDA

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %% [markdown]
# YO SE QUE ESTAN CANSADOS, PERO AUN FALTA

# %% [markdown]
# ![images.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# MATRIZ DE CORRELACION

# %%
"""
Este método es la herramienta estándar para evaluar la relación lineal
(o no lineal) por pares entre todas las columnas numéricas.
"""

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %%
"""
Selección de Predictores:
Ayuda a identificar variables independientes (X) que tienen una fuerte
correlación con la variable dependiente (Y), indicando su potencial poder
predictivo.

Detección de Multicolinealidad:
Es la función más crítica. La multicolinealidad ocurre cuando dos o más variables
independientes están altamente correlacionadas entre sí (cercanas a ±1).
Esto puede hacer que los coeficientes de regresión (β^​) sean inestables,
difíciles de interpretar o estadísticamente insignificantes.
"""

# %%
import pandas as pd
import seaborn as sns # Opcional: para visualizar como mapa de calor
import matplotlib.pyplot as plt # Opcional: para mostrar la gráfica

# 1. Crear un DataFrame (ejemplo)
data = {
    'Precio': [100, 150, 200, 120, 180],
    'Tamaño_m2': [50, 75, 100, 60, 90],
    'Habitaciones': [1, 2, 3, 1, 2]
}
df = pd.DataFrame(data)

# 2. Calcular la matriz de correlación (por defecto usa Pearson)
matriz_correlacion = df.corr()

print("Matriz de Correlación:")
print(matriz_correlacion)
# Out:
# Matriz de Correlación:
#                 Precio  Tamaño_m2  Habitaciones
# Precio        1.000000   1.000000      0.942128
# Tamaño_m2     1.000000   1.000000      0.942128
# Habitaciones  0.942128   0.942128      1.000000

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)
