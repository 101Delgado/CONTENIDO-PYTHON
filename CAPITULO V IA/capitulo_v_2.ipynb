# %% [markdown]
# CONTINUAMOS...

# %% [markdown]
# ![b6f75295f19e925b043825896dd81351.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # REGRESION LOGISTICA

# %%
"""
La regresión logística es un modelo estadístico que se utiliza principalmente
para problemas de clasificación en el que se busca predecir la probabilidad
de que un evento ocurra o que una instancia pertenezca a una clase determinada.
A diferencia de la regresión lineal, la variable dependiente es una variable
dicotómica o categórica.
(generalmente con solo dos valores, como 0 o 1, "sí" o "no", "enfermo" o "sano")
"""

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %%
"""
la combinacion lineal de X_i es denominada logit y se
denota por S.
"""

# %% [markdown]
# OK, TRABAJEMOS EN UN PAR DE CONCEPTOS

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %%
"""
recuerden lo que les habia dicho sobre la probabilidad...
"""

"""
la probabilidad de que un evento A NO OCURRA es igual a la
probabilidad de que el evento complemento ocurra
"""

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %% [markdown]
# AUN ASI ESTA DIFICIL CALCULAR DICHA PROBABILIDAD

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)

# %%
"""
NOTA:

el Log esta en base e
"""

# %%
"""
entonces ya entendimos el calculo que va a llevar a cabo para entender que
valor va a tomar la probabilidad de una variable aleatoria Y
"""

"""
como se calculan los betas
"""

# %% [markdown]
# ![3D.png](data:image/png;base64,...)

# %% [markdown]
# COMO LO HACEMOS

# %% [markdown]
# ![3D.png](data:image/png;base64,...)

# %%
"""
LA FUNCION DE COSTOS EN CUESTION
"""

# %% [markdown]
# ![3D.png](data:image/png;base64,...)

# %%
"""
LAS COSAS QUE APARECEN ALLI SON
"""

# %% [markdown]
# ![3D.png](data:image/png;base64,...)

# %% [markdown]
# CONTINUAMOS

# %% [markdown]
# ![3D.png](data:image/png;base64,...)

# %% [markdown]
# ![3D.png](data:image/png;base64,...)

# %% [markdown]
# ![3D.png](data:image/png;base64,...)

# %% [markdown]
# ![3D.png](data:image/png;base64,...)

# %%
"""e
α es un hiperparámetro, lo que significa que su valor debe ser definido
por el usuario (o por una búsqueda automatizada) antes de que
comience el entrenamiento del modelo.
Valores comunes suelen estar entre 0.1,0.01 o 0.001.
"""

# %% [markdown]
# ![3D.png](data:image/png;base64,...)

# %% [markdown]
# ![3D.png](data:image/png;base64,...)

# %% [markdown]
# COMO SABEMOS QUE TAN BIEN ESTA CALIBRADO NUESTRO MODELO DE REGRESION LOGISTICA

# %% [markdown]
# ![3D.png](data:image/png;base64,...)

# %% [markdown]
# TERMINOLOGIA

# %% [markdown]
# ![3D.png](data:image/png;base64,...)

# %% [markdown]
# AHORA...

# %% [markdown]
# ![hay-que-alocarnos11636849903.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ARBOLES DE DESICION

# %% [markdown]
# ![hay-que-alocarnos11636849903.jpg](data:image/jpeg;base64,...)

# %%
"""
Un árbol de decisión es, en esencia, una serie de preguntas jerárquicas sobre
las características de los datos, que conducen a una predicción.
Se compone de tres tipos principales de nodos:
"""

# %% [markdown]
# ![hay-que-alocarnos11636849903.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# POR EJEMPLO

# %% [markdown]
# ![hay-que-alocarnos11636849903.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![hay-que-alocarnos11636849903.jpg](data:image/jpeg;base64,...)
