# %% [markdown]
# # **EN EL CAPITULO DE HOY VEREMOS...**

# %% [markdown]
# # ALGORITMOS DE ORDENAMIENTO 👩‍💻

# %%
"""
BURBUJA

SELECCION

INSERCCION
"""

# %% [markdown]
# # ORDENAMIENTO BURBUJA 🎈

# %%
"""
es un algoritmo de ordenamiento simple que funciona revisando repetidamente la lista a ordenar
y comparando cada par de elementos adyacentes,
intercambiándolos de posición si están en el orden incorrecto.
"""

# Como funciona?

"""
1) Se compara el primer elemento con el segundo. Si el primero es mayor que el segundo, se intercambian.
2) Se compara el segundo con el tercero. Si el segundo es mayor, se intercambian.
3) Este proceso continúa hasta el final de la lista. Al finalizar la primera pasada, el elemento más grande estará en la última posición.
4) La siguiente pasada hace lo mismo, pero se detiene una posición antes, ya que el último elemento ya está en su lugar correcto.
5) El proceso se repite, reduciendo el rango de comparación en cada pasada, hasta que no se realiza ningún intercambio.
"""

# %% [markdown]
# ![IMAGEN_1.gif](data:image/gif;base64,...)

# %%
# Existe un problema...

#que pasa cuando las listas son muy grandes

"""
Su complejidad de tiempo en el peor y caso promedio es de O(n2), donde n es el número de elementos.
"""

# Veremos un ejemplo de su codigo

# %%
def ordenamiento_burbuja(lista):
    """
    Ordena una lista de números de forma ascendente utilizando el algoritmo de ordenamiento burbuja.
    """
    n = len(lista)

    # Recorre todos los elementos de la lista
    for i in range(n):
        # La variable 'intercambio_hecho' optimiza el algoritmo.
        # Si no se hace ningún intercambio en una pasada, la lista ya está ordenada.
        intercambio_hecho = False

        # Últimos i elementos ya están en su lugar, así que no es necesario volver a compararlos.
        for j in range(0, n - i - 1):

            # Compara elementos adyacentes
            if lista[j] > lista[j + 1]:

                # Intercambia los elementos si están en el orden incorrecto
                lista[j], lista[j + 1] = lista[j + 1], lista[j]
                print(f"ordenando {lista}")
                intercambio_hecho = True

        # Si no se hizo ningún intercambio en esta pasada, la lista está ordenada
        if not intercambio_hecho:
            break

    return lista

# Ejemplo de uso:
mi_lista = [64, 34, 25, 12, 22, 11, 90, 50]
lista_ordenada = ordenamiento_burbuja(mi_lista)
print("Lista ordenada:", lista_ordenada)
# Out:
# ordenando [34, 64, 25, 12, 22, 11, 90, 50]
# ordenando [34, 25, 64, 12, 22, 11, 90, 50]
# ordenando [34, 25, 12, 64, 22, 11, 90, 50]
# ordenando [34, 25, 12, 22, 64, 11, 90, 50]
# ordenando [34, 25, 12, 22, 11, 64, 90, 50]
# ordenando [34, 25, 12, 22, 11, 64, 50, 90]
# ordenando [25, 34, 12, 22, 11, 64, 50, 90]
# ordenando [25, 12, 34, 22, 11, 64, 50, 90]
# ordenando [25, 12, 22, 34, 11, 64, 50, 90]
# ordenando [25, 12, 22, 11, 34, 64, 50, 90]
# ordenando [25, 12, 22, 11, 34, 50, 64, 90]
# ordenando [12, 25, 22, 11, 34, 50, 64, 90]
# ordenando [12, 22, 25, 11, 34, 50, 64, 90]
# ordenando [12, 22, 11, 25, 34, 50, 64, 90]
# ordenando [12, 11, 22, 25, 34, 50, 64, 90]
# ordenando [11, 12, 22, 25, 34, 50, 64, 90]
# Lista ordenada: [11, 12, 22, 25, 34, 50, 64, 90]

# %%
"""
hecho de forma recursiva
"""
def burbuja_recursiva(lista, n):
    """
    Ordena una lista de forma ascendente utilizando el algoritmo de ordenamiento burbuja de manera recursiva.

    Args:
        lista (list): La lista de elementos a ordenar.
        n (int, opcional): El número de elementos a considerar en la pasada actual.
                            Por defecto, se toma la longitud completa de la lista.
    """

    print(f"n vale: {n}")


    # Caso base de la recursión: si la lista tiene 1 elemento o menos, ya está ordenada.
    if n <= 1:
        return

    # Realiza una pasada del ordenamiento burbuja
    for i in range(n - 1):
        if lista[i] > lista[i + 1]:
            # Intercambia los elementos si están en el orden incorrecto
            lista[i], lista[i + 1] = lista[i + 1], lista[i]

    # Llama a la función recursivamente para ordenar el resto de la lista.
    # El elemento más grande de la pasada anterior ya está en su lugar,
    # por lo que el siguiente llamado se enfoca en 'n-1' elementos.
    burbuja_recursiva(lista, n - 1)

# ---

# Ejemplo de uso
mi_lista = [64, 34, 25, 12, 22, 11, 90,50]
print("Lista original:", mi_lista)

burbuja_recursiva(mi_lista, len(mi_lista))

print("Lista ordenada:", mi_lista)
# Out:
# Lista original: [64, 34, 25, 12, 22, 11, 90, 50]
# n vale: 8
# n vale: 7
# n vale: 6
# n vale: 5
# n vale: 4
# n vale: 3
# n vale: 2
# n vale: 1
# Lista ordenada: [11, 12, 22, 25, 34, 50, 64, 90]

# %% [markdown]
# # ALGORITMO DE SELECCION

# %%
"""
es un método de ordenamiento simple y en sitio que divide la lista en dos partes
una sublista ordenada a la izquierda y una sublista desordenada a la derecha.
"""

# %%
"""
su complejidad de tiempo es de O(n2)
en todos los casos (mejor, promedio y peor),
lo que lo hace ineficiente para grandes conjuntos de datos.
"""

# %% [markdown]
# ![IMAGEN2.gif](data:image/gif;base64,...)

# %%
def ordenamiento_por_seleccion(lista):
    """
    Ordena una lista de números de forma ascendente utilizando el algoritmo de ordenamiento por selección.
    """
    n = len(lista)

    # Recorre cada elemento de la lista para colocarlo en su posición correcta
    for i in range(n):
        # Asume que el elemento actual es el mínimo
        indice_minimo = i

        # Busca el elemento mínimo en el resto de la lista (sublista desordenada)
        for j in range(i + 1, n):
            if lista[j] < lista[indice_minimo]:
                indice_minimo = j

        # Intercambia el elemento mínimo encontrado con el primer elemento de la sublista desordenada
        # Este paso coloca el elemento más pequeño en su posición ordenada
        print(lista)
        lista[i], lista[indice_minimo] = lista[indice_minimo], lista[i]

    return lista

# Ejemplo de uso:
mi_lista = [64, 25, 12, 22, 11]
lista_ordenada = ordenamiento_por_seleccion(mi_lista)
print("Lista ordenada:", lista_ordenada)
# Out:
# [64, 25, 12, 22, 11]
# [11, 25, 12, 22, 64]
# [11, 12, 25, 22, 64]
# [11, 12, 22, 25, 64]
# [11, 12, 22, 25, 64]
# Lista ordenada: [11, 12, 22, 25, 64]

# %% [markdown]
# RECURSIVAMENTE... (NO SE SI ESO ES UNA PALABRA 🙂)

# %%
def seleccion_recursiva(lista, inicio=0):
    """
    Ordena una lista de forma ascendente utilizando el algoritmo de ordenamiento por selección
    de manera recursiva.

    Args:
        lista (list): La lista de elementos a ordenar.
        inicio (int): El índice de la sublista desde donde buscar el elemento mínimo.
    """
    # Caso base: si el índice de inicio es igual a la longitud de la lista,
    # significa que ya hemos recorrido todos los elementos y la lista está ordenada.
    if inicio >= len(lista) - 1:
        return

    # Encuentra el índice del elemento mínimo en la sublista desde 'inicio'
    indice_minimo = inicio
    for i in range(inicio + 1, len(lista)):
        if lista[i] < lista[indice_minimo]:
            indice_minimo = i
    print(lista)
    # Intercambia el elemento mínimo con el elemento en la posición 'inicio'
    lista[inicio], lista[indice_minimo] = lista[indice_minimo], lista[inicio]

    # Llama a la función recursivamente para ordenar el resto de la lista.
    # El nuevo 'inicio' es 'inicio + 1'.
    seleccion_recursiva(lista, inicio + 1)
    print(f"hola soy {inicio}")
# ---

# Ejemplo de uso
mi_lista = [64, 25, 12, 22, 11, 4]
print("Lista original:", mi_lista)

seleccion_recursiva(mi_lista)

print("Lista ordenada:", mi_lista)
# Out:
# Lista original: [64, 25, 12, 22, 11, 4]
# [64, 25, 12, 22, 11, 4]
# [4, 25, 12, 22, 11, 64]
# [4, 11, 12, 22, 25, 64]
# [4, 11, 12, 22, 25, 64]
# [4, 11, 12, 22, 25, 64]
# hola soy 4
# hola soy 3
# hola soy 2
# hola soy 1
# hola soy 0
# Lista ordenada: [4, 11, 12, 22, 25, 64]

# %% [markdown]
# # ALGORITMO DE INSERCCION

# %%
"""
es un algoritmo de ordenamiento simple y eficiente para pequeñas cantidades de datos. A diferencia de otros métodos,
este algoritmo construye la lista final ordenada un elemento a la vez,
tomando los elementos de la lista de entrada y "insertándolos" en la posición correcta de la lista ya ordenada.
"""

# %%
# OTRA VEZ...

"""
Su complejidad de tiempo es de O(n2) en el peor y caso promedio
"""

# %% [markdown]
# ![IMAGEN3.gif](data:image/gif;base64,...)

# %%
def ordenamiento_por_insercion(lista):
    """
    Ordena una lista de números de forma ascendente utilizando el algoritmo de ordenamiento por inserción.
    """
    # Recorre la lista desde el segundo elemento hasta el final
    for i in range(1, len(lista)):

        # 'clave' es el elemento actual que queremos insertar en la sublista ordenada
        clave = lista[i]

        # 'j' es el índice del último elemento de la sublista ordenada
        j = i - 1

        # Mueve los elementos de la sublista ordenada que son mayores que la 'clave'
        # un lugar a la derecha para hacer espacio.
        while j >= 0 and clave < lista[j]:
            lista[j + 1] = lista[j]
            j -= 1
        print(lista)
        # Inserta la 'clave' en su posición correcta
        lista[j + 1] = clave
        print(lista)
    return lista

# Ejemplo de uso:
mi_lista = [12, 11, 13, 5, 6]
lista_ordenada = ordenamiento_por_insercion(mi_lista)
print("Lista ordenada:", lista_ordenada)
# Out:
# [12, 12, 13, 5, 6]
# [11, 12, 13, 5, 6]
# [11, 12, 13, 5, 6]
# [11, 12, 13, 5, 6]
# [11, 11, 12, 13, 6]
# [5, 11, 12, 13, 6]
# [5, 11, 11, 12, 13]
# [5, 6, 11, 12, 13]
# Lista ordenada: [5, 6, 11, 12, 13]

# %% [markdown]
# OTRA VEZ...

# %%
def insercion_recursiva(lista, n):
    """
    Ordena una lista de forma ascendente utilizando el algoritmo de ordenamiento por inserción
    de manera recursiva.

    Args:
        lista (list): La lista de elementos a ordenar.
        n (int): El número de elementos a considerar en la llamada actual.
    """
    # Caso base de la recursión: si la sublista tiene un solo elemento o menos,
    # ya está ordenada y no hay nada que hacer.
    if n <= 1:
        return

    # Llama a la función recursivamente para ordenar los primeros 'n-1' elementos.
    insercion_recursiva(lista, n - 1)
    print(f"hola soy {n}")
    # El 'n-1' elemento (último de la sublista desordenada) es la clave a insertar.
    clave = lista[n - 1]
    j = n - 2

    # Mueve los elementos de la sublista ordenada que son mayores que la 'clave'
    # un lugar a la derecha.
    while j >= 0 and clave < lista[j]:
        lista[j + 1] = lista[j]
        j -= 1

    print(lista)
    # Inserta la clave en su posición correcta.
    lista[j + 1] = clave

# ---

# Ejemplo de uso
mi_lista = [12, 11, 13, 5, 6, 8]
n = len(mi_lista)
print("Lista original:", mi_lista)

insercion_recursiva(mi_lista, n)

print("Lista ordenada:", mi_lista)
# Out:
# Lista original: [12, 11, 13, 5, 6, 8]
# hola soy 2
# [12, 12, 13, 5, 6, 8]
# hola soy 3
# [11, 12, 13, 5, 6, 8]
# hola soy 4
# [11, 11, 12, 13, 6, 8]
# hola soy 5
# [5, 11, 11, 12, 13, 8]
# hola soy 6
# [5, 6, 11, 11, 12, 13]
# Lista ordenada: [5, 6, 8, 11, 12, 13]

# %% [markdown]
# EJERCICIO

# %%
"""
CREAR UN CODIGO PARA SABER SI UNA PALABRA ES UN ANAGRAMA DE LA OTRA
"""
# Utilizaremos los algoritmos de ordenamiento

"""
tip 1: vamos a ordenar alfabeticamente las palabras
tip 2: ambas palabras ordenadas deben ser iguales para que una sea un angrama de la otra
tip 3: hay que modificar los algoritmos de ordenamiento que hicimos
tip 4: usaremos insersion o seleccion
"""

# %% [markdown]
# ![images.jpg](data:image/jpeg;base64,...)

# %%
def ordenamiento_por_seleccion(lista):
    """
    Ordena una lista de números de forma ascendente utilizando el algoritmo de ordenamiento por selección.
    """
    n = len(lista)

    # Recorre cada elemento de la lista para colocarlo en su posición correcta
    for i in range(n):
        # Asume que el elemento actual es el mínimo
        indice_minimo = i

        # Busca el elemento mínimo en el resto de la lista (sublista desordenada)
        for j in range(i + 1, n):
            if ord(lista[j]) < ord(lista[indice_minimo]):
                indice_minimo = j

        # Intercambia el elemento mínimo encontrado con el primer elemento de la sublista desordenada
        # Este paso coloca el elemento más pequeño en su posición ordenada
        if i == n-1:
          print(f"{lista}\n")
        else:
          print(lista)
        lista[i], lista[indice_minimo] = lista[indice_minimo], lista[i]

    return lista

palabra_1 = "vaca"
palabra_2 = "cava"

if ordenamiento_por_seleccion(list(palabra_1)) == ordenamiento_por_seleccion(list(palabra_2)):
  print("es un anagrama")
else:
  print("no es un anagrama")
# Out:
# ['v', 'a', 'c', 'a']
# ['a', 'v', 'c', 'a']
# ['a', 'a', 'c', 'v']
# ['a', 'a', 'c', 'v']
#
# ['c', 'a', 'v', 'a']
# ['a', 'c', 'v', 'a']
# ['a', 'a', 'v', 'c']
# ['a', 'a', 'c', 'v']
#
# es un anagrama

# %% [markdown]
# # La manera en la que se realizo por su profe

# %%
def anagrama(palabra_1, palabra_2) -> bool:

  return sorted(palabra_1.lower()) == sorted(palabra_2.lower())

print(anagrama("papa", "mama"))
print(sorted("listen"))
print(anagrama("Listen", "Silent"))
# Out:
# False
# ['e', 'i', 'l', 'n', 's', 't']
# True

# %% [markdown]
# ![cb25529b7169ccdf69945bd9e0513fb4.png](data:image/png;base64,...)

# %% [markdown]
# AHORA LO HAREMOS RECURSIVO...

# %% [markdown]
# ![images.jpg](data:image/jpeg;base64,...)

# %%
"""

LO DEJAREMOS PARA OTRA OCASION

"""

# %% [markdown]
# ![cb25529b7169ccdf69945bd9e0513fb4.png](data:image/png;base64,...)

# %% [markdown]
# #**ORDENAMIENTO POR FUSION**

# %%
"""
es un algoritmo de ordenamiento eficiente y estable que se basa en la técnica de "divide y vencerás".
Es un método recursivo que divide la  lista en sublistas más pequeñas hasta
que cada una contiene un solo elemento, y luego fusiona (combina) esas sublistas de forma ordenada.
"""

# %% [markdown]
# ![Merge-sort-example-300px.gif](data:image/gif;base64,...)

# %%
"""
tiene una complejidad de tiempo de O(nlogn) en todos los casos (mejor, promedio y peor)
"""

# %% [markdown]
# # CODIGO

# %%
"""
HAY BASTANTE RECURSIVIDAD
"""

# %% [markdown]
# ![MR3.jpg](data:image/jpeg;base64,...)

# %%
def merge_sort(lista):
    """
    Ordena una lista de forma ascendente utilizando el algoritmo de ordenamiento por fusión.
    """
    # Caso base de la recursión: si la lista tiene un solo elemento o está vacía,
    # ya está ordenada.
    if len(lista) > 1:

        # 1. DIVIDIR: Encuentra el punto medio de la lista y la divide en dos mitades.
        mitad = len(lista) // 2
        mitad_izquierda = lista[:mitad]
        mitad_derecha = lista[mitad:]

        # Llama a merge_sort de forma recursiva en cada mitad
        merge_sort(mitad_izquierda)
        merge_sort(mitad_derecha)

        # 2. FUSIONAR: Combina las dos mitades ordenadas en una sola lista
        i = j = k = 0

        print(f"antes del ciclo while {lista} con mitad izquierda {mitad_izquierda} con mitad derecha {mitad_derecha}")
        # Fusiona las sublistas temporales en la lista original
        while i < len(mitad_izquierda) and j < len(mitad_derecha):
            print(f"se compara {mitad_izquierda[i]} con {mitad_derecha[j]}")
            if mitad_izquierda[i] < mitad_derecha[j]:
                lista[k] = mitad_izquierda[i]
                i += 1
            else:
                lista[k] = mitad_derecha[j]
                j += 1
            k += 1
        print(f"despues del primer while {lista} con mitad izquierda {mitad_izquierda} con mitad derecha {mitad_derecha}")
        # Carga los elementos restantes de la mitad izquierda, si los hay
        while i < len(mitad_izquierda):
            lista[k] = mitad_izquierda[i]
            i += 1
            k += 1
        print(f"despues del segundo while {lista} con mitad izquierda {mitad_izquierda} con mitad derecha {mitad_derecha}")
        # Carga los elementos restantes de la mitad derecha, si los hay
        while j < len(mitad_derecha):
            lista[k] = mitad_derecha[j]
            j += 1
            k += 1
        print(f"despues del tercer while {lista} con mitad izquierda {mitad_izquierda} con mitad derecha {mitad_derecha}\n")
# ---

# Ejemplo de uso:
mi_lista = [38,13, 27,13, 43, 3, 9, 82, 10]
print("Lista original:", mi_lista)

merge_sort(mi_lista)

print("Lista ordenada:", mi_lista)
# Out:
# Lista original: [38, 13, 27, 13, 43, 3, 9, 82, 10]
# antes del ciclo while [38, 13] con mitad izquierda [38] con mitad derecha [13]
# se compara 38 con 13
# despues del primer while [13, 13] con mitad izquierda [38] con mitad derecha [13]
# despues del segundo while [13, 38] con mitad izquierda [38] con mitad derecha [13]
# despues del tercer while [13, 38] con mitad izquierda [38] con mitad derecha [13]
#
# antes del ciclo while [27, 13] con mitad izquierda [27] con mitad derecha [13]
# se compara 27 con 13
# despues del primer while [13, 13] con mitad izquierda [27] con mitad derecha [13]
# despues del segundo while [13, 27] con mitad izquierda [27] con mitad derecha [13]
# despues del tercer while [13, 27] con mitad izquierda [27] con mitad derecha [13]
#
# antes del ciclo while [38, 13, 27, 13] con mitad izquierda [13, 38] con mitad derecha [13, 27]
# se compara 13 con 13
# se compara 13 con 27
# se compara 38 con 27
# ...

# %% [markdown]
# VAMOS A REVISARLO PASO A PASO

# %% [markdown]
# ![MR2.jpg](data:image/jpeg;base64,...)

# %%
# 1. DIVIDIR: Encuentra el punto medio de la lista y la divide en dos mitades.
mitad = len(lista) // 2
mitad_izquierda = lista[:mitad]
mitad_derecha = lista[mitad:]

# %%
# Llama a merge_sort de forma recursiva en cada mitad
merge_sort(mitad_izquierda)
merge_sort(mitad_derecha)

# %%
"""
ESTO SE EJECUTA AL TERMINAR LAS LLAMADAS RECURSIVAS
"""
# 2. FUSIONAR: Combina las dos mitades ordenadas en una sola lista
i = j = k = 0

# Fusiona las sublistas temporales en la lista original
while i < len(mitad_izquierda) and j < len(mitad_derecha):
  if mitad_izquierda[i] < mitad_derecha[j]:
    lista[k] = mitad_izquierda[i]
    i += 1
  else:
    lista[k] = mitad_derecha[j]
    j += 1
  k += 1

# %% [markdown]
# ![MR1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # COMPAREMOS ESTOS ALGORITMOS

# %% [markdown]
# https://www.geogebra.org/calculator

# %% [markdown]
# EN ESTE LINK PODREMOS MANIPULAR LAS FUNCIONES PARA VER CUAL ES MAS EFICIENTE

# %% [markdown]
# ![MR5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# REVISAREMOS EL ULTIMO ALGORITMO DE ORDENAMIENTO POR HOY

# %% [markdown]
# # EL ORDENAMIENTO RAPIDO

# %%
"""
es un algoritmo de ordenamiento muy popular y eficiente que también se basa en la técnica de "divide y vencerás".
Fue desarrollado por Tony Hoare y, en la práctica,
suele ser más rápido que otros algoritmos de ordenamiento de su misma complejidad, como el ordenamiento por fusión.
"""

"""
La complejidad de tiempo de Quicksort en el caso promedio y mejor caso es de O(nlogn)
"""

# %%
def ordenamiento_rapido(lista):
    """
    Ordena una lista de forma ascendente utilizando el algoritmo de ordenamiento rápido.
    """
    # Llama a la función auxiliar que realiza la recursión
    _ordenamiento_rapido_aux(lista, 0, len(lista) - 1)

def _ordenamiento_rapido_aux(lista, inicio, fin):
    """
    Función auxiliar recursiva para el ordenamiento rápido.
    """
    if inicio < fin:
        # 1. PARTIR: Se obtiene el índice del pivote después de la partición.
        indice_particion = particion(lista, inicio, fin)

        # 2. VENCER: Se hacen llamadas recursivas a las dos sublistas
        _ordenamiento_rapido_aux(lista, inicio, indice_particion - 1)  # Sublista izquierda
        _ordenamiento_rapido_aux(lista, indice_particion + 1, fin)     # Sublista derecha

def particion(lista, inicio, fin):
    """
    Función de partición que reorganiza la lista alrededor de un pivote.
    En este caso, se elige el último elemento como pivote.
    """
    # 1. SELECCIONAR EL PIVOTE: En este caso, el último elemento
    pivote = lista[fin]

    # 'i' es el índice del elemento más pequeño, que se usará para el intercambio
    i = inicio - 1


    # Recorre la lista desde el inicio hasta el fin - 1
    for j in range(inicio, fin):
        # Si el elemento actual es menor o igual al pivote
        if lista[j] <= pivote:
            # Incrementa el índice del elemento más pequeño
            i += 1
            # Intercambia los elementos
            lista[i], lista[j] = lista[j], lista[i]
            print(lista)


    # Intercambia el pivote con el elemento en la posición correcta (i + 1)
    lista[i + 1], lista[fin] = lista[fin], lista[i + 1]
    print(f"con el cambio de pivote {lista}")
    # Devuelve la posición final del pivote
    return i + 1

# ---

# Ejemplo de uso:
mi_lista = [10, 7, 8, 2, 1, 5] #-> [2,7,8,10,1,5] -> [2,1,8,10,7,5] -> [2,1,5,10,7,8] ->[1,2,5,10,7,8] -> [1,2,5,7,10,8]
# -> [1,2,5,7,8,10]
print("Lista original:", mi_lista)

ordenamiento_rapido(mi_lista)

print("Lista ordenada:", mi_lista)
# Out:
# Lista original: [10, 7, 8, 2, 1, 5]
# [2, 7, 8, 10, 1, 5]
# [2, 1, 8, 10, 7, 5]
# con el cambio de pivote [2, 1, 5, 10, 7, 8]
# con el cambio de pivote [1, 2, 5, 10, 7, 8]
# [1, 2, 5, 7, 10, 8]
# con el cambio de pivote [1, 2, 5, 7, 8, 10]
# Lista ordenada: [1, 2, 5, 7, 8, 10]

# %% [markdown]
# ![MR4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# FIN
#
# O NO...
